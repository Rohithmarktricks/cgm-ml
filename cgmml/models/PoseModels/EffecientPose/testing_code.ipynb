# %%
sample_file = '/home/azureuser/cloudfiles/code/Users/rbanka/scans_blur/314e0720-cc84-11ed-8f48-378f8bcadd5a/rgb/2'
# https://rbanka1.centralindia.instances.azureml.ms/tree/Users/rbanka/
lite_model = "/home/azureuser/cloudfiles/code/Users/rbanka/EfficientPose/models/tflite/EfficientPoseII_LITE.tflite"
# tf_lite_model = "models/tflite/EfficientPoseII_LITE.tflite"

# %%
from model_inference import main_fn
# Out:
# 2023-09-21 05:52:01.708634: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-21 05:52:02.854386: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-09-21 05:52:02.854474: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# ...

# %%
coordinates, image = main_fn(sample_file, lite_model)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/rbanka1/code/Users/rbanka/EfficientPose/final_deploy/helpers.py:179: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   resized_array = rescale(source_array, scale, multichannel=True)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
coordinates
# Out:
# {'head_top': array([269, 179]),
#  'upper_neck': array([256, 253]),
#  'right_shoulder': array([289, 272]),
#  'right_elbow': array([195, 275]),
#  'right_wrist': array([207, 388]),
#  'thorax': array([263, 270]),
#  'left_shoulder': array([225, 266]),
#  'left_elbow': array([200, 286]),
#  'left_wrist': array([209, 400]),
#  'pelvis': array([254, 402]),
#  'right_hip': array([258, 407]),
#  'right_knee': array([206, 406]),
#  'right_ankle': array([279, 512]),
#  'left_hip': array([246, 399]),
#  'left_knee': array([207, 414]),
#  'left_ankle': array([226, 505]),
#  'left_ground': array([231, 530]),
#  'right_ground': array([304, 549])}

# %%
# !python model_inference.py '/home/azureuser/cloudfiles/code/Users/rbanka/scans_blur/314e0720-cc84-11ed-8f48-378f8bcadd5a/rgb/2' "/home/azureuser/cloudfiles/code/Users/rbanka/EfficientPose/models/tflite/EfficientPoseII_LITE.tflite" >> sample_output.txt
